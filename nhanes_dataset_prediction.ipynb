# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
data = pd.read_csv('data_nhanes.csv')

# %%
data.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  109263.0      66.0       2.0       1.0       2.0       NaN       5.0
# 1  109264.0      66.0       2.0       2.0      13.0       NaN       1.0
# 2  109265.0      66.0       2.0       1.0       2.0       NaN       3.0
# 3  109266.0      66.0       2.0       2.0      29.0       NaN       5.0
# 4  109267.0      66.0       1.0       2.0      21.0       NaN       2.0
#
#    RIDRETH3  RIDEXMON  DMDBORN4  ...  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  \
# 0       6.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 1       1.0       2.0       1.0  ...       2.0      1.0       2.0       2.0
# 2       3.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 3       6.0       2.0       2.0  ...       2.0      1.0       2.0       2.0
# 4       2.0       NaN       2.0  ...       2.0      NaN       NaN       NaN
#
#    AIALANGA      WTINTPRP      WTMECPRP  SDMVPSU  SDMVSTRA  INDFMPIR
# ...

# %%
print(data.RIAGENDR.value_counts())
# Out:
# 2.0    7839
# 1.0    7721
# Name: RIAGENDR, dtype: int64

# %%
df = pd.DataFrame(data)

# %%
data.replace({'RIAGENDR':{1.0:'Male',2.0:'Female'}}, inplace=True)

# %%
data.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  109263.0      66.0       2.0     Male       2.0       NaN       5.0
# 1  109264.0      66.0       2.0   Female      13.0       NaN       1.0
# 2  109265.0      66.0       2.0     Male       2.0       NaN       3.0
# 3  109266.0      66.0       2.0   Female      29.0       NaN       5.0
# 4  109267.0      66.0       1.0   Female      21.0       NaN       2.0
#
#    RIDRETH3  RIDEXMON  DMDBORN4  ...  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  \
# 0       6.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 1       1.0       2.0       1.0  ...       2.0      1.0       2.0       2.0
# 2       3.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 3       6.0       2.0       2.0  ...       2.0      1.0       2.0       2.0
# 4       2.0       NaN       2.0  ...       2.0      NaN       NaN       NaN
#
#    AIALANGA      WTINTPRP      WTMECPRP  SDMVPSU  SDMVSTRA  INDFMPIR
# ...

# %%
sns.countplot(data, x='RIAGENDR')
# Out:
# <Axes: xlabel='RIAGENDR', ylabel='count'>

# %%
data_heart = pd.read_csv('data_cardio.csv')

# %%
data_heart.head()
# Out:
#        SEQN  CDQ001  CDQ002  CDQ003  CDQ004  CDQ005  CDQ006  CDQ009A  CDQ009B  \
# 0  109271.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN      NaN
# 1  109274.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN      NaN
# 2  109282.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN      NaN
# 3  109283.0     1.0     1.0     2.0     1.0     1.0     2.0      NaN      NaN
# 4  109284.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN      NaN
#
#    CDQ009C  CDQ009D  CDQ009E  CDQ009F  CDQ009G  CDQ009H  CDQ008  CDQ010
# 0      NaN      NaN      NaN      NaN      NaN      NaN     2.0     1.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN     NaN     2.0
# 2      NaN      NaN      NaN      NaN      NaN      NaN     2.0     1.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN     1.0     1.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN     NaN     2.0

# %%
print(data_heart.CDQ001.value_counts())
# Out:
# 2.0    4533
# 1.0    1896
# 9.0       4
# Name: CDQ001, dtype: int64

# %%
df1 = pd.DataFrame(data_heart)

# %%
df1
# Out:
#           SEQN  CDQ001  CDQ002  CDQ003  CDQ004  CDQ005  CDQ006  CDQ009A  \
# 0     109271.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN
# 1     109274.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN
# 2     109282.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN
# 3     109283.0     1.0     1.0     2.0     1.0     1.0     2.0      NaN
# 4     109284.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN
# ...        ...     ...     ...     ...     ...     ...     ...      ...
# 6428  124815.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN
# 6429  124817.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN
# 6430  124818.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN
# 6431  124821.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN
# 6432  124822.0     1.0     2.0     NaN     NaN     NaN     NaN      NaN
#
#       CDQ009B  CDQ009C  CDQ009D  CDQ009E  CDQ009F  CDQ009G  CDQ009H  CDQ008  \
# ...

# %%
data_heart.replace({'CDQ001':{1.0:'Pain',2.0:'No-Pain'}}, inplace=True)

# %%
data_heart.head()
# Out:
#        SEQN   CDQ001  CDQ002  CDQ003  CDQ004  CDQ005  CDQ006  CDQ009A  \
# 0  109271.0     Pain     2.0     NaN     NaN     NaN     NaN      NaN
# 1  109274.0  No-Pain     NaN     NaN     NaN     NaN     NaN      NaN
# 2  109282.0     Pain     2.0     NaN     NaN     NaN     NaN      NaN
# 3  109283.0     Pain     1.0     2.0     1.0     1.0     2.0      NaN
# 4  109284.0  No-Pain     NaN     NaN     NaN     NaN     NaN      NaN
#
#    CDQ009B  CDQ009C  CDQ009D  CDQ009E  CDQ009F  CDQ009G  CDQ009H  CDQ008  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN     2.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN     2.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN     1.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN     NaN
#
#    CDQ010
# 0     1.0
# 1     2.0
# 2     1.0
# 3     1.0
# 4     2.0

# %%
sns.countplot(data_heart, x='CDQ001')
# Out:
# <Axes: xlabel='CDQ001', ylabel='count'>
